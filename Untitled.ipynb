# %% [markdown]
# <a href="https://colab.research.google.com/github/TristanMulder/meuportfolio/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

def buscar_clima(cidade: str, latitude: float, longitude: float) -> pd.DataFrame:
  url = (
      "https://api.open-meteo.com/v1/forecast"
        f"?latitude={latitude}&longitude={longitude}"
        "&current=temperature_2m,relative_humidity_2m,wind_speed_10m"
  )

  response = request.get(url, timeout=10)
  response.raise_for_status()

  data = response.jason()
  atual =data["current"]

  return pd.DataFrame([{
      "cidade": cidade,
        "temperatura": atual["temperature_2m"],
        "umidade": atual["relative_humidity_2m"],
        "vento": atual["wind_speed_10m"],
        "data_hora": atual["time"]
  }])
